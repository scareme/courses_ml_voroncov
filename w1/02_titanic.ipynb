# %% [markdown]
#     Описание в: 'doc/w1_05_titanic-assignment.pdf'

# %%
import pandas as pd

# %%
def save_answer(name, value):
    with open('data/titanic-assignment_' + name + '.txt', 'w', encoding='utf-8') as f:
        f.write(value)

# %%
PATH_TO_DATA = 'data/titanic.csv'

# %%
df = pd.read_csv(PATH_TO_DATA)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 1.Какое количество мужчин и женщин ехало на корабле? В качестве
# ответа приведите два числа через пробел

# %%
men = df.Sex.value_counts().male
women = df.Sex.value_counts().female

f'{men} {women}'
# Out:
# '577 314'

# %%
save_answer('1', f'{men} {women}')

# %% [markdown]
# 2.Какой части пассажиров удалось выжить? Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
round(df['Survived'].mean()*100, 2)
# Out:
# 38.38

# %%
save_answer('2', str(round(df['Survived'].mean()*100, 2)))

# %% [markdown]
# 3.Какую долю пассажиры первого класса составляли среди всех пассажиров? Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
round(df['Pclass'].value_counts(normalize=True)[1]*100, 2)
# Out:
# 24.239999999999998

# %%
save_answer('3', str(round(df['Pclass'].value_counts(normalize=True)[1]*100, 2)))

# %% [markdown]
# 4.Какого возраста были пассажиры? Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.

# %%
age_mean = df['Age'].mean()
age_median = int(df['Age'].median())

f'{age_mean:.2f} {age_median}'
# Out:
# '29.70 28'

# %%
save_answer('4', f'{age_mean:.2f} {age_median}')

# %% [markdown]
# 5.Коррелируют ли число братьев/сестер/супругов с числом родителей/детей? Посчитайте корреляцию Пирсона между признаками SibSp и Parch.

# %%
round(df['SibSp'].corr(df['Parch']), 2)
# Out:
# 0.40999999999999998

# %%
save_answer('5', str(round(df['SibSp'].corr(df['Parch']), 2)))

# %% [markdown]
# Какое самое популярное женское имя на корабле? Извлеките из полного имени пассажира (колонка Name) его личное имя (First Name). Это задание — типичный пример того, с чем сталкивается специалист по анализу данных. Данные очень разнородные и шумные, но из них требуется извлечь необходимую информацию. Попробуйте вручную разобрать несколько значений столбца Name и выработать правило для извлечения имен, а также разделения их на женские и мужские.

# %%
for el in df[df['Sex']=='female']['Name'].str.split(','):
    value = el[1].strip()
    print(value)
    if ('Mrs.' in value)&('(' in value):
        print('\t', value.split('(')[1].strip().split(' ')[0].strip())
    else:
        print('\t', el[1].strip().split(' ')[1])
# Out:
# Mrs. John Bradley (Florence Briggs Thayer)
# 	 Florence
# Miss. Laina
# 	 Laina
# Mrs. Jacques Heath (Lily May Peel)
# 	 Lily
# Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 	 Elisabeth
# Mrs. Nicholas (Adele Achem)
# 	 Adele
# Miss. Marguerite Rut
# 	 Marguerite
# Miss. Elizabeth
# 	 Elizabeth
# Miss. Hulda Amanda Adolfina
# 	 Hulda
# Mrs. (Mary D Kingcome)
# 	 Mary
# Mrs. Julius (Emelia Maria Vandemoortele)
# 	 Emelia
# Mrs. Fatima
# 	 Fatima
# Miss. Anna "Annie"
# 	 Anna
# Miss. Torborg Danira
# 	 Torborg
# Mrs. Carl Oscar (Selma Augusta Emilia Johansson)
# 	 Selma
# Miss. Ellen "Nellie"
# 	 Ellen
# Mrs. William Augustus (Marie Eugenie)
# 	 Marie
# Miss. Mary Agatha
# 	 Mary
# Miss. Augusta Maria
# 	 Augusta
# Miss. Jamila
# 	 Jamila
# Mrs. Johan (Johanna Persdotter Larsson)
# 	 Johanna
# Mrs. William John Robert (Dorothy Ann Wonnacott)
# 	 Dorothy
# Miss. Simonne Marie Anne Andree
# 	 Simonne
# Miss. Margaret Delia
# 	 Margaret
# Miss. Bridget
# 	 Bridget
# ...

# %%
def get_first_name(el):
    value = el.split(',')[1].strip()
    #print(value)
    if ('Mrs.' in value)&('(' in value):
        #print('\t', value.split('(')[1].strip().split(' ')[0].strip())
        return value.split('(')[1].strip().split(' ')[0].strip()
    else:
        #print('\t', el.split(',')[1].strip().split(' ')[1])
        return el.split(',')[1].strip().split(' ')[1]

# %%
df['First Name'] = df.Name.apply(get_first_name)

# %%
df[df.Sex=='female']['First Name'].value_counts().nlargest(1).index[0]
# Out:
# 'Anna'

# %%
save_answer('6', df[df.Sex=='female']['First Name'].value_counts().nlargest(1).index[0])
